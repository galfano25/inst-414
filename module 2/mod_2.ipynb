# %%
import json
import networkx as nx
routes = {}

"""
json data is grouped by arrival airport 

this is a directional, weighted relationship
"""
with open("data.json", "r") as file:
    data = json.load(file)
    for arr_airport in data:
        for flight in arr_airport:
            dept_airport = flight['estDepartureAirport']
            arr_airport = flight['estArrivalAirport']

            if (dept_airport != None and arr_airport) and (dept_airport != arr_airport):
                if arr_airport not in routes:
                    routes[arr_airport] = {}
                
                if dept_airport not in routes[arr_airport]:
                    routes[arr_airport][dept_airport] = 0
                
                routes[arr_airport][dept_airport] += 1

print(routes)
# Out:
# {'LOWG': {'LOAG': 1, 'EDDM': 11, 'LZKZ': 1, 'LOWW': 11, 'LTAI': 3, 'EDDF': 13, 'EDFB': 1, 'LOGK': 1, 'LCLK': 1, 'EDLW': 1, 'LEPA': 1, 'LSZH': 4, 'EDGS': 1, 'LJBL': 2, 'EDLA': 1, 'EDDL': 2, 'EDDB': 2, 'EGKB': 1, 'LHBP': 1, 'LGKO': 1, 'LHSM': 1, 'LOXZ': 2, 'LOWS': 1, 'LOAN': 1, 'EDDH': 2, 'EDTM': 1, 'EDQM': 1, 'LFMN': 1, 'LJMB': 1, 'LOKW': 1, 'LFMD': 1, 'LFKC': 1, 'EKSB': 1, 'LSZR': 1, 'EDDC': 1, 'LIPZ': 1, 'LGRP': 1, 'LIPV': 1}, 'LOWI': {'LSZM': 1, 'EDDK': 1, 'LGKO': 1, 'LIPX': 1, 'EHAM': 3, 'LOWW': 10, 'ETHN': 1, 'LSZB': 1, 'LFKJ': 1, 'LGRP': 1, 'LKPM': 1, 'EDFE': 1, 'EDML': 1, 'EGKK': 2, 'EDDH': 2, 'LEBL': 2, 'LFLB': 1, 'LSGG': 1, 'LKPR': 1, 'EBAW': 1, 'LFMD': 1, 'LSZH': 2, 'LIRA': 1, 'EDJA': 1, 'LIPB': 1, 'LDLO': 1, 'LOWS': 1, 'LFKC': 1, 'EGGW': 1, 'EDSB': 1, 'LFBO': 1, 'EGBB': 1, 'EDDP': 1, 'EGCC': 1, 'ETHA': 1, 'EGPH': 1, 'EDDB': 1}, 'LOWK': {'LEAL': 1, 'LZIB': 1, 'LOWW': 2}, 'LOWL': {'LOLO': 1, 'LOLH': 1, 'LTAI': 3, 'EDDP': 2, 'LHBP': 2, 'EDLV': 1, 'EGSS': 1, 'EDDK': 1, 'EDDG': 1, 'LIRA': 1, 'LGRP': 2, 'LIPZ': 1, 'EIDW': 1, 'LFTZ': 1, 'LFMN': 1, 'EPWA': 1, 'EDDS': 1, 'LGKO': 1}, 'LOWS': {'EDDF': 18, 'ELLX': 2, 'LIML': 2, 'EGKK': 7, 'LOAN': 1, 'EGGW': 3, 'EDFZ': 1, 'LOIH': 1, 'EDTX': 2, 'LSZH': 2, 'LGRP': 4, 'EDDL': 6, 'EDDH': 4, 'EDSB': 2, 'OMDB': 2, 'EDME': 1, 'EDMS': 1, 'LSGG': 1, 'LTFM': 4, 'LBSF': 1, 'EGSS': 2, 'EPPO': 1, 'LEPA': 3, 'LYBE': 1, 'LSZA': 1, 'EDTL': 1, 'LIMJ': 1, 'EDDB': 3, 'LWSK': 1, 'LROP': 1, 'LFPB': 2, 'LEIB': 1, 'LFPM': 1, 'EDLP': 1, 'EDDC': 1, 'EFNU': 1, 'LIPZ': 2, 'LGAV': 1, 'LEBL': 1, 'LOWW': 1, 'LKPR': 1, 'EHAM': 1, 'LIPQ': 1, 'EIDW': 1, 'EDDM': 1, 'EDJA': 1, 'EDDK': 2, 'LGKR': 1, 'LFKC': 1, 'LTAI': 1, 'OLBA': 1, 'EDFE': 1, 'EGNT': 1, 'EDLN': 1, 'EKRK': 1, 'EDTM': 1, 'LPFR': 1, 'LFRS': 1, 'LGKO': 1, 'EGNX': 1, 'ESGG': 1, 'EGCC': 1, 'EGPF': 1, 'EGBB': 1, 'EKCH': 1, 'ESSA': 1}, 'LOWW': {'LSZH': 39, 'LROP': 26, 'VIDP': 2, 'BKPR': 9, 'EHAM': 39, 'EGKK': 10, 'LIME': 11, 'LEMG': 12, 'EGLL': 37, 'EDDB': 46, 'OMDB': 10, 'LTFM': 15, 'LBSF': 23, 'LTFJ': 16, 'LDZL': 2, 'LPPT': 9, 'LFPG': 38, 'EDDM': 27, 'EGGW': 4, 'EDDF': 54, 'ESSA': 21, 'EKBI': 3, 'LIPZ': 27, 'EGPH': 5, 'LEBL': 23, 'LEAL': 3, 'LHBP': 18, 'EIDW': 10, 'LOWG': 13, 'LKPR': 21, 'LYBE': 25, 'EDDV': 16, 'EYKA': 1, 'KJFK': 5, 'EDDP': 8, 'LOWS': 1, 'LEMD': 17, 'LIPE': 14, 'LIMC': 26, 'EBMB': 30, 'LSZM': 7, 'LPFR': 3, 'LFMN': 21, 'LTAI': 17, 'EDDH': 28, 'EKCH': 24, 'LSGG': 15, 'EGSS': 15, 'EDDL': 28, 'EDDK': 25, 'LGAV': 9, 'EFHK': 10, 'LIRF': 25, 'LZTT': 1, 'EDDS': 20, 'EBCI': 5, 'LWOH': 2, 'EPWA': 27, 'LOWI': 10, 'LDZA': 9, 'LLBG': 15, 'LEPA': 15, 'ELLX': 9, 'EVRA': 11, 'EPKK': 14, 'LSZR': 5, 'BIKF': 5, 'LOKR': 1, 'EBLG': 2, 'LWSK': 7, 'LZKZ': 9, 'LYNI': 1, 'EGCC': 4, 'LMML': 8, 'LQBK': 1, 'LFHC': 5, 'LBWV': 2, 'LJLJ': 1, 'LCLK': 7, 'LIML': 1, 'LGRP': 8, 'LKTB': 2, 'EDMO': 2, 'EKRK': 1, 'LGKR': 2, 'LPPR': 6, 'ENGM': 6, 'LICJ': 6, 'LEZL': 3, 'LGTS': 7, 'LGKO': 5, 'LFTH': 2, 'EETN': 3, 'LPMA': 2, 'LOAV': 1, 'LIRQ': 2, 'LD57': 2, 'EPRZ': 2, 'LZIB': 1, 'EPMO': 2, 'LEIB': 5, 'EDLW': 1, 'LGSA': 4, 'LOAN': 1, 'LFOB': 6, 'LFPB': 2, 'LDPL': 2, 'EBBR': 1, 'LFML': 4, 'EPPO': 1, 'LGMK': 4, 'ESGG': 2, 'LIPX': 2, 'LFPO': 2, 'LIRP': 1, 'LIPR': 2, 'LFLB': 1, 'LFRS': 1, 'RJAA': 2, 'EDFM': 1, 'LBBG': 2, 'EYVI': 6, 'LFOV': 1, 'EGLF': 4, 'LFLP': 1, 'LW67': 2, 'LDZD': 3, 'EGKB': 2, 'EDDW': 2, 'LDRG': 1, 'EPKT': 3, 'UGTB': 3, 'EGNS': 1, 'EHEH': 1, 'LGKN': 1, 'LIEA': 1, 'LHFP': 2, 'LFMD': 2, 'LOXT': 1, 'LCPH': 2, 'LKMT': 1, 'LHSM': 1, 'LSZL': 1, 'LPCS': 1, 'LFKC': 1, 'OKBK': 1, 'EGWU': 1, 'LGSY': 1, 'LGLM': 1, 'LOAS': 1, 'EGMC': 1, 'EGMD': 1, 'EDVY': 1, 'EDLV': 1}, 'UMMS': {'UUEE': 7, 'OMDB': 2, 'UMKK': 1, 'UUDD': 3, 'VIDP': 1, 'UGTB': 1}, 'EBAW': {'EHSE': 2, 'LEAL': 2, 'EINN': 1, 'LEPA': 1, 'EBCI': 1, 'LSZM': 1, 'GMMW': 1, 'EGLC': 1, 'LFMD': 5, 'EPWA': 2, 'LEMP': 2, 'LOWI': 1, 'EHRD': 1, 'EKCH': 1, 'EDDS': 1, 'EBMB': 3, 'EGLF': 5, 'LSGG': 1, 'EBST': 1, 'LEIB': 3, 'LFKJ': 1, 'EGKA': 1, 'GMTT': 1, 'LHBP': 1, 'EIDW': 1, 'BIRK': 1, 'EHAM': 3, 'EGTE': 1, 'LEMG': 2, 'LFMN': 2 ...

# %%
g = nx.DiGraph()
g.clear()

for arr_airport, sources in routes.items():
    g.add_node(arr_airport, label=arr_airport)
    for source in sources.keys():
        g.add_node(source, label=source)

seen = set()
for arr_airport, sources in routes.items():
    for source, count in sources.items():
        edge = (source, arr_airport)
        if edge not in seen:
            g.add_edge(source, arr_airport, weight=count, label=f"{count}")
            seen.add(edge)

nx.write_graphml(g, "graph.graphml")

# %% [markdown]
# sort of error - it appears in the graphml file that the directions are messed up. after some thought, it could be that the nx is organizing nodes and edges differently when it writes to a file. for example - when i print routes, it says the number of times EDDM had arrived at LOWG was 11. However, if I printed the edges with data, the first thing I see is LOWG -> EDDM with a different value. I thought the graph was not writing correclty, but upon further inspection, it seems to just organize the nodes differently.

# %%
"""why degree centrality (in degree)?
question is which city gets the busiest.
regular degree centrality does not account for weights (e.g. amount of arrivals).
eigenvector centrality does not account for weighting, but pagerank does.
pagerank gives more weight to neighbors of important nodes, but if there was an airport that had a lot of layovers on the way to the final 
destination, this would be giving more weight to airports that happen to have direct connections to more populus airports. since we're considering
which cities are most popular, not which airports, whether an airport is neighboring to an important airport seems redundant.
betweenness centrality - considering the fact that layovers are common, a flight with high betweenness centrality could just mean there's a lot of layovers there, not a lot of actual visitors. 
closeness centrality - more closely indicates how easily each city can reach other cities 
"""

centrality = nx.in_degree_centrality(g)
for airport in centrality:
    print(airport, centrality[airport])

top = 3
for node in sorted(centrality, key=centrality.get, reverse=True)[:top]:
    print(node, centrality[node])
# Out:
# LOWG 0.03653846153846154
# LOAG 0.0
# EDDM 0.16153846153846155
# LZKZ 0.014423076923076924
# LOWW 0.14807692307692308
# LTAI 0.1076923076923077
# EDDF 0.18942307692307694
# EDFB 0.0
# LOGK 0.0
# LCLK 0.06538461538461539
# EDLW 0.057692307692307696
# LEPA 0.11153846153846154
# LSZH 0.1701923076923077
# EDGS 0.0
# LJBL 0.0
# EDLA 0.0
# EDDL 0.11730769230769231
# EDDB 0.15096153846153848
# EGKB 0.0
# LHBP 0.11057692307692309
# LGKO 0.07019230769230769
# LHSM 0.0
# LOXZ 0.0
# LOWS 0.06346153846153846
# LOAN 0.0
# EDDH 0.11442307692307693
# EDTM 0.0
# EDQM 0.0
# LFMN 0.15961538461538463
# LJMB 0.0
# LOKW 0.0
# LFMD 0.0
# LFKC 0.0
# EKSB 0.0
# LSZR 0.0
# EDDC 0.032692307692307694
# LIPZ 0.08653846153846154
# LGRP 0.10576923076923078
# LIPV 0.0
# LOWI 0.035576923076923075
# LSZM 0.0
# EDDK 0.1125
# LIPX 0.05
# EHAM 0.19230769230769232
# ETHN 0.0
# LSZB 0.0
# LFKJ 0.03173076923076923
# LKPM 0.0
# EDFE 0.0
# EDML 0.0
# EGKK 0.11923076923076924
# LEBL 0.1528846153846154
# LFLB 0.0
# LSGG 0.1375
# LKPR 0.13365384615384615
# EBAW 0.05
# LIRA 0.06826923076923078
# EDJA 0.058653846153846154
# LIPB 0.0
# LDLO 0.0
# EGGW 0.14807692307692308
# EDSB 0.01730769230769231
# LFBO 0.07403846153846154
# EGBB 0.09615384615384616
# EDDP 0.08076923076923077
# EGCC 0.1375
# ETHA 0.0
# EGPH 0.11923076923076924
# LOWK 0.0028846153846153848
# LEAL 0.11634615384615385
# LZIB 0.05384615384615385
# LOWL 0.01730769230769231
# LOLO 0.0
# LOLH 0.0
# EDLV 0.037500000000000006
# EGSS 0.1778846153846154
# EDDG 0.046153846153846156
# EIDW 0.1451923076923077
# LFTZ 0.0
# EPWA 0.1201923076923077
# EDDS 0.09615384615384616
# ELLX 0.10096153846153846
# LIML 0.09903846153846155
# EDFZ 0.0
# LOIH 0.0
# EDTX 0.0
# OMDB 0.0
# EDME 0.0
# EDMS 0.0
# LTFM 0.13846153846153847
# LBSF 0.08076923076923077
# EPPO 0.0625
# LYBE 0.0903846153846154
# LSZA 0.0
# EDTL 0.0
# LIMJ 0.04326923076923077
# LWSK 0.038461538461538464
# LROP 0.09326923076923077
# LFPB 0.0
# LEIB 0.08942307692307692
# LFPM 0.0
# EDLP 0.0019230769230769232
# EFNU 0.0
# LGAV 0.10865384615384616
# LIPQ 0.022115384615384617
# LGKR 0.05096153846153846
# OLBA 0.0
# EGNT 0.05384615384615385
# EDLN 0.0
# EKRK 0.0
# LPFR 0.1
# LFRS 0.06442307692307693
# EGNX 0.07307692307692308
# ESGG 0.06346153846153846
# EGPF 0.013461538461538462
# EKCH 0.13173076923076923
# ESSA 0.10480769230769231
# VIDP 0.0
# BKPR 0.02980769230769231
# LIME 0.1076923076923077
# LEMG 0.1423076923076923
# EGLL 0.15000000000000002
# LTFJ 0.07500000000000001
# LDZL 0.0
# LPPT 0.08173076923076923
# LFPG 0.1625
# EKBI 0.07019230769230769
# EDDV 0.06538461538461539
# EYKA 0.03076923076923077
# KJFK 0.0
# LEMD 0.13461538461538464
# LIPE 0.1028846153846154
# LIMC 0.13076923076923078
# EBMB 0.0
# EFHK 0.08942307692307692
# LIRF 0.13846153846153847
# LZTT 0.0
# EBCI 0.1
# LWOH 0.0
# LDZA 0.010576923076923078
# LLBG 0.0
# EVRA 0.08461538461538462
# EPKK 0.0951923076923077
# BIKF 0.06153846153846154
# LOKR 0.0
# EBLG 0.04326923076923077
# LYNI 0.010576923076923078
# LMML 0.09903846153846155
# LQBK 0.0
# LFHC 0.0
# LBWV 0.0
# LJLJ 0.035576923076923075
# LKTB 0.025
# EDMO 0.0
# LPPR 0.09807692307692309
# ENGM 0.10673076923076924
# LICJ 0.05673076923076924
# LEZL 0.06346153846153846
# LGTS 0.07307692307692308
# LFTH 0.03461538461538462
# EETN 0.04423076923076923
# LPMA 0.046153846153846156
# LOAV 0.0
# LIRQ 0.035576923076923075
# LD57 0.0
# EPRZ 0.0
# EPMO 0.04134615384615385
# LGSA 0.05961538461538462
# LFOB 0.05961538461538462
# LDPL 0.025961538461538463
# EBBR 0.0951923076923077
# LFML 0.09903846153846155
# LGMK 0.035576923076923075
# LFPO 0.09230769230769231
# LIRP 0.07884615384615384
# LIPR 0.0
# RJAA 0.0
# EDFM 0.0
# LBBG 0.03653846153846154
# EYVI 0.058653846153846154
# LFOV 0.0
# EGLF 0.0
# LFLP 0.0
# LW67 0.0
# LDZD 0.004807692307692308
# EDDW 0.03653846153846154
# LDRG 0.0
# EPKT 0.060576923076923084
# UGTB 0.028846153846153848
# EGNS 0.0
# EHEH 0.06346153846153846
# LGKN 0.0
# LIEA 0.02980769230769231
# LHFP 0.0
# LOXT 0.0
# LCPH 0.05
# LKMT 0.0
# LSZL 0.0
# LPCS 0.0
# OKBK 0.0
# EGWU 0.0
# LGSY 0.0
# LGLM 0.0
# LOAS 0.0
# EGMC 0.032692307692307694
# EGMD 0.0
# EDVY 0.0
# UMMS 0.0057692307692307696
# UUEE 0.0038461538461538464
# UMKK 0.0
# UUDD 0.006730769230769231
# EHSE 0.0
# EINN 0.049038461538461545
# GMMW 0.0
# EGLC 0.06826923076923078
# LEMP 0.0
# EHRD 0.05384615384615385
# EBST 0.0
# EGKA 0.0
# GMTT 0.0
# BIRK 0.0
# EGTE 0.02403846153846154
# LIPU 0.0
# EGJB 0.0
# EBZR 0.0
# EGTK 0.0
# EGPE 0.020192307692307693
# EGNM 0.057692307692307696
# LFBD 0.07884615384615384
# KOPF 0.0
# EBUL 0.0
# EBGB 0.0
# LSGL 0.0
# LKKU 0.0
# EBOS 0.021153846153846155
# KEWR 0.0
# KORD 0.0
# LFLL 0.06923076923076923
# DAAG 0.0
# GMFO 0.0
# KCVG 0.0
# LEAM 0.01826923076923077
# LPAR 0.0
# LSGK 0.0
# LEGE 0.026923076923076925
# LTBY 0.0
# GMTA 0.0
# ESOE 0.0
# LPMT 0.0
# ENBR 0.046153846153846156
# GMTN 0.0
# LRBC 0.0
# LTGP 0.0
# LBPD 0.0
# KMIA 0.0
# KDFW 0.0
# OMDW 0.0
# DBBB 0.0
# LFKB 0.032692307692307694
# LFKF 0.027884615384615386
# LEDS 0.0
# LIPH 0.04230769230769231
# LFBH 0.0
# EGNR 0.0
# LIMZ 0.0
# LIBP 0.02403846153846154
# LFMP 0.0
# LFGJ 0.0
# EPWR 0.06153846153846154
# LEST 0.025961538461538463
# LFTW 0.0
# LIMF 0.037500000000000006
# LFBE 0.004807692307692308
# UGKO 0.019230769230769232
# LEMH 0.04134615384615385
# EGLD 0.0
# LFBT 0.0
# EPLK 0.0
# LFMK 0.0
# LPPD 0.025961538461538463
# EICK 0.046153846153846156
# EBKT 0.0
# LFAT 0.0
# LFQJ 0.0
# LRCV 0.0
# LRTR 0.011538461538461539
# LFCR 0.0
# LDRI 0.0019230769230769232
# LFMQ 0.0
# VHHH 0.0
# LEZG 0.014423076923076924
# EDDN 0.07500000000000001
# OMSJ 0.0
# EGGP 0.06826923076923078
# LKCS 0.0
# FAOR 0.0
# OERY 0.0
# EGSH 0.0
# EBBN 0.0
# EGHH 0.0
# EBAM 0.0
# EHTE 0.0
# EHMZ 0.0
# LELH 0.0
# EHGG 0.019230769230769232
# EGJJ 0.049038461538461545
# EGSC 0.0
# EPRJ 0.0
# KHPN 0.0
# EIPT 0.0
# LQSA 0.0009615384615384616
# EGGD 0.0826923076923077
# ETAR 0.0
# EGFF 0.026923076923076925
# EGNV 0.0
# EDRY 0.0
# LBLS 0.0
# LTBA 0.0
# LBTG 0.0
# LDZI 0.0
# EDFH 0.04134615384615385
# LBWN 0.0057692307692307696
# LGIO 0.0
# LDOS 0.0
# LDSP 0.0019230769230769232
# ENTO 0.014423076923076924
# ESSP 0.0
# EKYT 0.026923076923076925
# EGAA 0.0451923076923077
# ENZV 0.016346153846153847
# ESMS 0.01826923076923077
# EPRA 0.0
# LGSM 0.020192307692307693
# LCRA 0.0
# EKAH 0.01730769230769231
# LKKM 0.0
# LKZN 0.0
# LKMB 0.0
# LKLT 0.0
# EDDR 0.0
# LOAU 0.0
# LKNY 0.0
# LKKC 0.0
# LKZD 0.0
# LKLB 0.0
# EDVE 0.0
# LESA 0.0
# LKVL 0.0
# EDTD 0.0
# LKPC 0.0
# LFMV 0.0
# LKHK 0.0
# LGKV 0.0
# LKRO 0.0
# ESSB 0.0
# LTFE 0.051923076923076926
# LIMP 0.0
# EDFC 0.0
# LBSB 0.0
# LFRB 0.03076923076923077
# LFMH 0.0
# LRBS 0.0
# EKRN 0.0
# EKKA 0.0
# EKOD 0.0
# EKVJ 0.0
# EKVH 0.0
# EDXF 0.0
# EKRD 0.0
# LSZC 0.0
# LGMT 0.019230769230769232
# EKAE 0.0
# EDHK 0.0
# KSFO 0.0
# EKKS 0.0
# EPGD 0.007692307692307693
# CYYZ 0.0
# EYPA 0.0
# EGPD 0.025961538461538463
# ENCN 0.011538461538461539
# RJTT 0.0
# EFTP 0.01730769230769231
# KTEB 0.0
# LFMT 0.011538461538461539
# EKRS 0.0
# KADS 0.0
# EKGL 0.0
# EKHG 0.0
# LFMI 0.0
# EEKA 0.0
# EPBD 0.0
# WSSS 0.0
# EEKE 0.0
# EFKU 0.0
# EERA 0.0
# KSEA 0.0
# EFJY 0.0
# ESSL 0.0
# EFKK 0.0
# EETU 0.0
# EFJO 0.0
# VTBS 0.0
# EFMA 0.0
# KLAX 0.0
# EELM 0.0
# ESSV 0.0
# ENVA 0.010576923076923078
# EFMN 0.0
# EFTU 0.006730769230769231
# EFOU 0.0009615384615384616
# ESCF 0.0
# ESSN 0.0
# LIPK 0.0
# EFJM 0.0
# EDWF 0.0
# LFNG 0.0
# LFKO 0.0
# LFQQ 0.025961538461538463
# LFST 0.028846153846153848
# LIRJ 0.0
# LFBS 0.0
# LFPN 0.0
# LFOZ 0.0
# LFRK 0.0
# LFLC 0.0
# LFLY 0.0
# LFBG 0.0
# LFOE 0.0
# EDXW 0.0
# LFRT 0.0
# LFBZ 0.0038461538461538464
# LFPT 0.0
# LFPV 0.0
# CYUL 0.0
# LFOJ 0.0
# LFMO 0.0
# LFJI 0.0
# LFSG 0.0
# LFBX 0.0
# LFRN 0.03076923076923077
# LFRE 0.0
# LFRL 0.0
# LFRU 0.0
# LFRF 0.0
# LFJR 0.0
# LFPZ 0.0
# LFEC 0.0
# LFRQ 0.0
# EGPK 0.035576923076923075
# LFQO 0.0
# LFEX 0.0
# LFOP 0.0
# LFQN 0.0
# EGTC 0.0
# LFAK 0.0
# DAON 0.0
# LFIX 0.0
# LFBP 0.0
# DAOO 0.0
# LICC 0.0
# LFNR 0.0
# LFOT 0.0
# LFNT 0.0
# LFNH 0.0
# LFLS 0.0
# LFMY 0.0
# LFJL 0.0
# LFNF 0.0
# EGHI 0.035576923076923075
# LFMA 0.0
# LFHI 0.0
# LFER 0.0
# EDLS 0.0
# LFFI 0.0
# LICP 0.0
# LFOK 0.0
# KATL 0.0
# LFMF 0.0
# KPHL 0.0
# LFGA 0.0
# LFRG 0.0
# KPWA 0.0
# KMMU 0.0
# LFMC 0.0
# KFLL 0.0
# EGNP 0.0
# EDQG 0.0
# KLAS 0.0
# EDHL 0.0
# LETZ 0.0
# EHBK 0.026923076923076925
# LSGT 0.0
# EGBJ 0.0
# KPBI 0.0
# LELN 0.0
# MMMX 0.0
# DAOI 0.0
# SBGL 0.0
# KIAD 0.0
# CYYC 0.0
# KMSP 0.0
# KBOS 0.0
# KDTW 0.0
# 05IN 0.0
# RKSI 0.0
# SAEZ 0.0
# SPJC 0.0
# LTBK 0.0
# LL1B 0.0
# KDEN 0.0
# CYQB 0.0
# VAJJ 0.0
# RJBB 0.0
# MMUN 0.0
# HECA 0.0
# CYMX 0.0
# MM28 0.0
# LERS 0.023076923076923078
# LIPY 0.013461538461538462
# LICB 0.013461538461538462
# LFBI 0.0
# LFCC 0.0
# EDAB 0.0
# LFAQ 0.0
# LFCA 0.0
# LFGF 0.0
# LFBU 0.0
# EGNH 0.0
# LFBF 0.0
# LEGT 0.0
# LFCV 0.0
# LFRH 0.0
# LFRZ 0.0
# EDHI 0.0
# LFQA 0.0
# EDNY 0.03076923076923077
# LFMW 0.0
# LOLW 0.0
# UASS 0.0
# OMAA 0.0
# UGSB 0.0
# ULLI 0.0028846153846153848
# UUWW 0.0057692307692307696
# URSS 0.0
# URMM 0.0
# EDNS 0.0
# EDNL 0.0
# EDWI 0.0
# EDNE 0.0
# LELC 0.0
# EDAZ 0.0
# LIMG 0.0
# ETNW 0.0
# KISP 0.0
# LKKB 0.0
# ETNG 0.0
# EPPW 0.0
# EDDE 0.0
# KBED 0.0
# EDQC 0.0
# EDTY 0.0
# EDDT 0.0
# EDAH 0.0
# KAUS 0.0
# EDAY 0.0
# EHLE 0.0
# EDCS 0.0
# EDVK 0.0
# EDWQ 0.0
# EDWU 0.0
# EDWX 0.0
# EDWG 0.0
# KSDF 0.0
# EIKN 0.01826923076923077
# ETHC 0.0
# LTBL 0.0
# LFRI 0.0
# LIPO 0.0
# EDKV 0.0
# LHSK 0.0
# EDGE 0.0
# EDKL 0.0
# EDLZ 0.0
# EDVW 0.0
# EDLI 0.0
# EDKU 0.0
# EDLU 0.0
# EDWC 0.0
# EGTF 0.0
# EGHQ 0.0
# ETHM 0.0
# EDLD 0.0
# EDCY 0.0
# EDUF 0.0
# EDBZ 0.0
# LKMH 0.0
# EDCM 0.0
# EDCJ 0.0
# EDOQ 0.0
# EDCT 0.0
# LJPZ 0.0
# EDLM 0.0
# EDLC 0.0
# LESB 0.0
# LTCG 0.008653846153846154
# 17FA 0.0
# KMCO 0.0
# EDFY 0.0
# LGSK 0.025
# KPHX 0.0
# KSAT 0.0
# CYVR 0.0
# LFLI 0.0
# EGAC 0.027884615384615386
# EDFN 0.0
# ESMQ 0.0
# SBKP 0.0
# KBWI 0.0
# PANC 0.0
# 47FD 0.0
# CSK8 0.0
# EGNJ 0.0
# LTFH 0.0
# HTZA 0.0
# KIAH 0.0
# ETOU 0.0
# EDRZ 0.0
# EIKY 0.011538461538461539
# KGSP 0.0
# KRFD 0.0
# LSZX 0.0
# EDSP 0.0
# EDTF 0.0
# EDSR 0.0
# EDQW 0.0
# EDXT 0.0
# EDHG 0.0
# EDKB 0.0
# EDHU 0.0
# EDRK 0.0
# EDHE 0.0
# ESMT 0.0
# EDHS 0.0
# LTBW 0.0
# EDXJ 0.0
# EDXL 0.0
# EDXM 0.0
# KABE 0.0
# EDXR 0.0
# EDWH 0.0
# EDVH 0.0
# EDVM 0.0
# ETHS 0.0
# EHBD 0.0
# EDVA 0.0
# RHST 0.0
# EKEB 0.0
# EDFV 0.0
# EDRO 0.0
# EDBM 0.0
# ETNH 0.0
# EDLE 0.0
# ETT1 0.0
# KSAN 0.0
# LEJR 0.011538461538461539
# KCLT 0.0
# LHPP 0.0
# LIMB 0.0
# EDMQ 0.0
# ETND 0.0
# EDLB 0.0
# LFCH 0.0
# EHTX 0.0
# EDWP 0.0
# EDWR 0.0
# ETWM 0.0
# EDWO 0.0
# EDBJ 0.0
# EDQT 0.0
# EDNC 0.0
# EDQX 0.0
# EDQH 0.0
# EDPO 0.0
# LFSH 0.0
# EDSE 0.0
# EDTZ 0.0
# EDTB 0.0
# EDSH 0.0
# ETNL 0.0
# LRCK 0.0
# KTTN 0.0
# ENTS 0.0
# OERK 0.0
# LGPA 0.0
# LGSO 0.0
# LGKA 0.0
# LGIK 0.0
# LXGB 0.0
# LGKY 0.0
# LG56 0.0
# ENHD 0.0038461538461538464
# ESOK 0.0
# ENBO 0.006730769230769231
# LDZB 0.0
# LGEL 0.0
# LGHI 0.0
# LTFD 0.0
# LSMP 0.0
# LKPD 0.0
# LKKV 0.0
# ESSD 0.0
# ESMX 0.0
# HECW 0.0
# LHPR 0.0
# LHKE 0.0
# KRDU 0.0
# KPIT 0.0
# KRME 0.0
# KBVY 0.0
# CYOW 0.0
# CYWG 0.0
# KYIP 0.0
# KDAL 0.0
# EIKH 0.0
# KJAX 0.0
# KCLE 0.0
# 49OH 0.0
# EPSW 0.0
# EPLL 0.0
# EGTR 0.0
# KGTB 0.0
# KALB 0.0
# LFNX 0.0
# KSCH 0.0
# NY72 0.0
# KRST 0.0
# LIDF 0.0
# LIRU 0.0
# LDPM 0.0
# LILR 0.0
# LILV 0.0
# LIPM 0.0
# LIDE 0.0
# LIDV 0.0
# LIPF 0.0
# LIDG 0.0
# LIPC 0.0
# LIRE 0.0
# LIQS 0.0
# LIDP 0.0
# LIDR 0.0
# LIDA 0.0
# EGLK 0.0
# EPKL 0.0
# LEPP 0.0
# LIDH 0.0
# LILN 0.0
# KFRG 0.0
# LFLU 0.0
# LIPL 0.0
# LILB 0.0
# LILG 0.0
# LECO 0.0
# LIMN 0.0
# LILC 0.0
# RCTP 0.0
# LIRZ 0.0028846153846153848
# LIAT 0.0
# KCHS 0.0
# KOXC 0.0
# 51GA 0.0
# OMAD 0.0
# LIRL 0.0
# LIDB 0.0
# LIPD 0.0
# LSGC 0.0
# LIQL 0.0
# KMKC 0.0
# EGVN 0.0
# KCHO 0.0
# LFAV 0.0
# ENJB 0.0
# EVAD 0.0
# EVGA 0.0
# EDBN 0.0
# EIWT 0.0
# EHTW 0.0
# KIND 0.0
# EGXG 0.0
# ELUS 0.0
# KHSV 0.0
# LZPP 0.0
# LFAM 0.0
# HLLM 0.0
# EGPN 0.0
# EGBO 0.0
# EHVK 0.0
# 35MN 0.0
# EHDB 0.0
# EHKD 0.0
# EHLW 0.0
# KSLC 0.0
# VOMM 0.0
# CYEG 0.0
# LHPA 0.0
# EDWN 0.0
# EHDS 0.0
# EHHO 0.0
# EGDX 0.0
# EHGR 0.0
# EGBN 0.0
# ENSO 0.0
# ENUL 0.0
# ENRG 0.0
# ENGK 0.0
# ENKJ 0.0
# ENNO 0.0
# EKGH 0.0
# ESGU 0.0
# ENRY 0.0
# ENBM 0.0
# ETSI 0.0
# ENEG 0.0
# EPKP 0.0
# EPKN 0.0
# EPKR 0.0
# EPOM 0.0
# EPSY 0.0
# EPRG 0.0
# EDBF 0.0
# EPPI 0.0
# EPZG 0.0
# EPBC 0.0
# EPPK 0.0
# EPSC 0.0057692307692307696
# EPHN 0.0
# ESKN 0.0057692307692307696
# EPKO 0.0
# EPBY 0.0
# ESFR 0.0
# LPPM 0.0
# KSTL 0.0
# SBBR 0.0
# LPEV 0.0
# LPAZ 0.0
# TXKF 0.0
# LEVT 0.0
# LPST 0.0
# EGHF 0.0
# HE12 0.0
# UNWW 0.0
# ULLP 0.0
# ULMM 0.0
# UHWW 0.0
# UBBG 0.0
# UUYS 0.0
# LYBJ 0.0
# LYZR 0.0
# LZSE 0.0
# LZSY 0.0
# LZZI 0.0
# LZNI 0.0
# LZDV 0.0
# LJNM 0.0
# LJPT 0.0
# ESOW 0.0
# GEML 0.0
# LEVX 0.0
# EDAM 0.0
# LEIG 0.0
# LEBZ 0.0
# LELL 0.0
# LESL 0.0
# LEBB 0.0009615384615384616
# LECI 0.0
# LEMU 0.0
# LEGR 0.0038461538461538464
# LEAX 0.0
# LFMU 0.0
# LECU 0.0
# LETF 0.0
# TJSJ 0.0
# KBLM 0.0
# KLGB 0.0
# LEMT 0.0
# ESGJ 0.0
# ESKX 0.0
# LEXJ 0.0028846153846153848
# KSAV 0.0
# LEHC 0.0
# LETO 0.0
# LPBJ 0.0
# LKVO 0.0
# ESTA 0.0
# ESNN 0.0
# ESIB 0.0
# ESNZ 0.0
# ESDF 0.0
# ESNS 0.0
# ESNL 0.0
# ESCM 0.0
# ESUK 0.0
# ESNQ 0.0
# EFLA 0.0
# LFHS 0.0
# LFRM 0.0
# LFSD 0.0
# LSGE 0.0
# LSMD 0.0
# LSGB 0.0
# LFDI 0.0
# LCEN 0.0
# EDQA 0.0
# LSGN 0.0
# LSZF 0.0
# EDSN 0.0
# LSZI 0.0
# KTPA 0.0
# LSPV 0.0
# EDKA 0.0
# OMRK 0.0
# FL35 0.0
# LW75 0.0
# MMIM 0.0
# LFCK 0.0
# LFDH 0.0
# UUBW 0.0
# UAUU 0.0
# ULAA 0.0
# USPP 0.0
# LTXE 0.0
# UWGG 0.0
# UIII 0.0
# LTBS 0.014423076923076924
# LTBV 0.0
# LTCB 0.0
# VGTJ 0.0
# OPLA 0.0
# USSS 0.0
# VNKT 0.0
# VGZR 0.0
# HTDA 0.0
# USSK 0.0
# HEBA 0.0
# URMT 0.0
# LTBJ 0.019230769230769232
# LTBR 0.0
# EGNE 0.0
# EGPT 0.0
# EGAD 0.0
# EGBM 0.0
# EGNG 0.0
# EGBW 0.0
# EGBL 0.0
# EGWC 0.0
# LHTL 0.0
# EGCV 0.0
# EGHS 0.0
# LFBL 0.0
# EGNL 0.0
# EG03 0.0
# EGVO 0.0
# EGDW 0.0
# EGKL 0.0
# EGHP 0.0
# EGHA 0.0
# EGBS 0.0
# EGLM 0.0
# EGFE 0.0
# EGTW 0.0
# EGYO 0.0
# EGHR 0.0
# EGCL 0.0
# EGBT 0.0
# EGQL 0.0
# EGHE 0.0
# EGLA 0.0
# EGSG 0.0
# CYTR 0.0
# KPNE 0.0
# EGUN 0.0
# EGQK 0.0
# EGPJ 0.0
# EGJA 0.0
# LFRO 0.0
# EGTB 0.0
# CT19 0.0
# EGVP 0.0
# LFRD 0.0
# LPVL 0.0
# EIME 0.0
# EGCJ 0.0
# EGXY 0.0
# EGCB 0.0
# EGTH 0.0
# EGKR 0.0
# EGOW 0.0
# EGCW 0.0
# EGUD 0.0
# EGMF 0.0
# EGHY 0.0
# EGML 0.0
# EGKE 0.0
# KPDX 0.0
# KBNA 0.0
# TBPB 0.0
# MBPV 0.0
# OM11 0.0
# KSGS 0.0
# VHSK 0.0
# 8TX7 0.0
# KMSY 0.0
# 6NJ9 0.0
# EGUP 0.0
# VABB 0.0
# YPPH 0.0
# EGBE 0.0
# KBFI 0.0
# EGHO 0.0
# KSFM 0.0
# EGYE 0.0
# KPMP 0.0
# 78VA 0.0
# EGHL 0.0
# EGSX 0.0
# EGKH 0.0
# EGSR 0.0
# EGYM 0.0
# EGDY 0.0
# KDSM 0.0
# MS62 0.0
# EGXH 0.0
# OMFJ 0.0
# KSJC 0.0
# LTBU 0.0
# LFPP 0.0
# EGCK 0.0
# EGBK 0.0
# EG64 0.0
# EGNC 0.0
# EGHJ 0.0
# EHAM 0.19230769230769232
# EDDF 0.18942307692307694
# EGSS 0.1778846153846154

# %% [markdown]
# "Most important" nodes: EHAM, EDDF, EGSS
#
# What airports are these?
# EHAM - AMS - Amsterdam Schiphol
# EDDF - FRA - Frankfurt
# EGSS - STN - London Stansted

# %%
top_100 = sorted(centrality, key=centrality.get, reverse=True)[:100]
g_top100 = g.subgraph(top_100).copy()


nx.write_graphml(g_top100, "top100.graphml")
